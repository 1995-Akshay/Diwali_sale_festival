# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\aksha\Week 9 Pandas\Diwali Sales Data.csv", encoding = "unicode_escape")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# Checking the shape and size of the dataframe
df.shape
# Out:
# (11251, 15)

# %%
# checking the first 10 rows of the dataframe contents
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
# checking the data To analyza the need for clearing area
df.info
# Out:
# <bound method DataFrame.info of        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# dropinng the balank and/ or unrelated column and saving the the dataframe

df.drop(["Status", "unnamed1"],axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
# checking null values in dataframe 

pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# droppping null values from the dataframe and saving it for future analysis
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# checking data types after the convertion
df["Amount"].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# renaming column for more clarity

df.rename(columns = {"Cust_name":"Customer_name", "Marital_Status":"Relationship_status"},inplace = True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Relationship_status', 'State', 'Zone', 'Occupation',
#        'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
# using describe () to check the description of "orders" and "Amount" column
df[["Orders","Amount"]].describe()
# Out:
#              Orders        Amount
# count  11239.000000  11239.000000
# mean       2.489634   9453.610858
# std        1.114967   5222.355869
# min        1.000000    188.000000
# 25%        2.000000   5443.000000
# 50%        2.000000   8109.000000
# 75%        3.000000  12675.000000
# max        4.000000  23952.000000

# %% [markdown]
# # EXPLORATORY DATA Analysis (EDA)

# %% [markdown]
# # BASE on Gender

# %%
# checking order placement data for potential pattern

ax = sns.countplot(x = "Gender", data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# checking order placed data fro potential pattern or trend  in purchasing power across genders
sales_gen = df.groupby(["Gender"], as_index = False) ["Amount"].sum().sort_values(by = "Amount", ascending = False)

ax = sns.barplot(x = "Gender", y = "Amount", data = sales_gen)

# %% [markdown]
# # Based on Age

# %%
# checking order placement data for potential pattern or trend  in purchasing  behaviour on "age group"

ax = sns.countplot(x = "Age Group", data = df, hue = "Gender")


for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Checking order placement data for potential or trends in purchasing power across "age Groups"

sales_age = df.groupby(["Age Group"], as_index = False) ["Amount"].sum().sort_values(by = "Amount",ascending = False)

ax = sns.barplot( x = "Age Group" , y = "Amount" ,data = sales_age)

for index, row in sales_age.iterrows():
    ax.text(index,row["Amount"],row["Amount"] ,ha ="center")

# %% [raw]
#  THe chart presented above indicate that age group of 26-35 made the higest number of purchase

# %% [markdown]
# # Based on States

# %%
# checking total number of order from top 10 states
sales_state = df.groupby(["State"],as_index = False)  ["Orders"].sum().sort_values(by = "Orders",ascending = False).head(10)

sns.set(rc={"figure.figsize":(20,5)})

ax = sns.barplot( x = "State" , y = "Orders",data = sales_state)

# %%
# Checking top 10 state based on amount spent

sales_state = df.groupby(["State"],as_index = False) ["Amount"].sum().sort_values(by="Amount",ascending = False).head(10)

sns.set(rc={"figure.figsize":(25,10)})

ax = sns.barplot(x = "State", y = "Amount",data = sales_state)

# %%
# checking the pattern of amount spent based on relationship status and gender

sales_state = df.groupby(["Relationship_status","Gender"],as_index = False) ["Amount"].sum().sort_values(by = "Amount",ascending = False)

sns.set(rc={"figure.figsize":(18,5)})

ax = sns.barplot(x = "Relationship_status" , y = "Amount",data = sales_state, hue = "Gender")

# %% [raw]
# Based on the above graphs it is evidence that the majority women

# %% [markdown]
# # BASED on Occupation

# %%
# Checking the order pattern based on occupation

ax = sns.countplot(x= "Occupation",data = df)

sns.set(rc={"figure.figsize":(18,5)})
for bar in ax.containers:
    ax.bar_label(bars)

# %%
# checking the pattern of amount spent based on occupation

sales_state = df.groupby(["Occupation"], as_index = False) ["Amount"].sum().sort_values(by="Amount",ascending = False)

sns.set(rc={"figure.figsize":(18,5)})
ax = sns.barplot(x="Occupation",y="Amount",data = sales_state)

# %% [markdown]
# # BASED ON PRODUCT CATERGORY

# %%
# checking the order pattern based on product_category

ax = sns.countplot(x= "Product_Category",data=df)

sns.set(rc={"figure.figsize":(20,5)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# checking the pattern of amount spent based  on product_category
sales_state = df. groupby(["Product_Category"],as_index = False)["Amount"].sum().sort_values(by="Amount",ascending = False).head(10)

sns.set(rc={"figure.figsize":(22,5)})
ax = sns.barplot(x="Product_Category",y= "Amount",data = sales_state)

# %% [markdown]
# The aforementioned graph indicate that the majority of products sold fall under the categories of food,Clothing and electronics

# %%
# checking the top top 10 sold the BASED ON PRODUCT_id
sales_state = df.groupby(["Product_ID"], as_index = False) ["Orders"].sum().sort_values(by = "Orders",ascending = False).head(10)
sns.set(rc ={"figure.figsize":(22,5)})
axn = sns.barplot(x= "Product_ID" , y = "Orders", data = sales_state)

# %% [markdown]
# # Conclusion

# %% [markdown]
# According to the analyzed data it can be determined that female individual who are married and age between 26 and 35 year and who work within the
# information Technology Healthcare and aviation sector in the state of UP MH and KN have a higher propensity to purchase product from catergories of food,clothing and Electronice
